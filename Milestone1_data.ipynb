# %%
from scipy.io import loadmat
import numpy as np
import matplotlib.pyplot as plt

# %%
# !wget http://ufldl.stanford.edu/housenumbers/train_32x32.mat
# Out:
# --2023-05-03 21:23:07--  http://ufldl.stanford.edu/housenumbers/train_32x32.mat
# Resolving ufldl.stanford.edu (ufldl.stanford.edu)... 171.64.68.10
# Connecting to ufldl.stanford.edu (ufldl.stanford.edu)|171.64.68.10|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 182040794 (174M) [text/plain]
# Saving to: ‘train_32x32.mat’
#
# train_32x32.mat     100%[===================>] 173.61M  12.9MB/s    in 15s
#
# 2023-05-03 21:23:23 (11.4 MB/s) - ‘train_32x32.mat’ saved [182040794/182040794]

# %%
# !wget http://ufldl.stanford.edu/housenumbers/test_32x32.mat
# Out:
# --2023-05-03 21:23:27--  http://ufldl.stanford.edu/housenumbers/test_32x32.mat
# Resolving ufldl.stanford.edu (ufldl.stanford.edu)... 171.64.68.10
# Connecting to ufldl.stanford.edu (ufldl.stanford.edu)|171.64.68.10|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 64275384 (61M) [text/plain]
# Saving to: ‘test_32x32.mat’
#
# test_32x32.mat      100%[===================>]  61.30M  14.8MB/s    in 7.6s
#
# 2023-05-03 21:23:35 (8.11 MB/s) - ‘test_32x32.mat’ saved [64275384/64275384]

# %%
train = loadmat('train_32x32.mat')
test = loadmat('test_32x32.mat')

# %%
train.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'X', 'y'])

# %%
X_train = train["X"].transpose([3, 2, 0, 1])
y_train = train["y"]

# %%
X_train.shape, y_train.shape
# Out:
# ((73257, 3, 32, 32), (73257, 1))

# %%
i=0
rgb_channel = 0
plt.imshow(X_train[i, rgb_channel])
plt.title(f"Label: {y_train[i]}")
# Out:
# Text(0.5, 1.0, 'Label: [1]')

# %% [markdown]
# # New Section

# %%
rgb_channel = 0
n=20
fig, ax = plt.subplots(4,5, figsize=(10, 10))
for i, ax in enumerate(ax.flatten()):
  ax.imshow(X_train[i,rgb_channel])
  ax.set_title(f"Label: {y_train[i]}")

fig.show()

# %%
## Replace the label==10 items with label=0
y_train = np.where(y_train==10, 0, y_train)

# %%
y_train[y_train==10]
# Out:
# array([], dtype=uint8)
